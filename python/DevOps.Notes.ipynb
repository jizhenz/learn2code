# %% [markdown]
# # DevOps @wikipedia
# https://en.wikipedia.org/wiki/DevOps
#
# # Continuous integration (CI) @wikipedia
# https://en.wikipedia.org/wiki/Continuous_integration
#
# 2 Best practices
#
# 2.1 Maintain a code repository
#
# 2.2 Automate the build
#
# 2.3 Make the build self-testing
#
# 2.4 Everyone commits to the baseline every day
#
# 2.5 Every commit (to baseline) should be built
#
# 2.6 Keep the build fast
#
# 2.7 Test in a clone of the production environment
#
# 2.8 Make it easy to get the latest deliverables
#
# 2.9 Everyone can see the results of the latest build
#
# 2.10 Automate deployment
#
# # Continuous Delivery (CD) @wikipedia
# https://en.wikipedia.org/wiki/Continuous_delivery
#
# # Monitoring
# #### Nagios:
# https://www.nagios.org/
#
# Open source solutions: https://www.nagios.org/projects/
#
# Python API: https://pypi.python.org/pypi/nagios-api
#
# Nagios Plugins: https://pypi.python.org/pypi/nagiosplugin/
#
# PyNag:
#
# http://pynag.org/
#
# https://github.com/pynag/pynag
#
# #### Sensu
# https://sensuapp.org/
#
# Sensu COre is free, run time: Ruby
#
# # Configuration
# #### Puppet
# https://en.wikipedia.org/wiki/Puppet_(software)
#
# #### Ansible
# https://en.wikipedia.org/wiki/Ansible_(software)
#
# #### Chef
# https://en.wikipedia.org/wiki/Chef_(software)
#
# #### SaltStack
#
# Salt platform or SaltStack is a Python-based open source configuration management and remote execution application. Supporting the "infrastructure-as-code" approach to deployment and cloud management, it competes primarily with Puppet, Chef, and Ansible.
#
# https://en.wikipedia.org/wiki/Salt_(software)
#
# http://saltstack.com/
#
# # CI/CD
#
# #### Jenkins:
# https://en.wikipedia.org/wiki/Jenkins_(software)
#
# #### Bamboo
# https://en.wikipedia.org/wiki/Bamboo_(software)
#
# #### Maven
# https://en.wikipedia.org/wiki/Apache_Maven
#
# Mianly for Java
#
# #### TeamCity
# https://en.wikipedia.org/wiki/TeamCity
#
# #### CI Software Comparison
# https://en.wikipedia.org/wiki/Comparison_of_continuous_integration_software
#
# # Artifact Management
#
# #### JFrog Artifactory
# https://www.jfrog.com/artifactory/
#
# https://www.jfrog.com/open-source/#os-arti
#
# http://sourceforge.net/projects/artifactory/
#
# Main writen in Java
#
# #### Nexus
# http://www.sonatype.com/nexus/product-overview
#
# Community: http://www.sonatype.org/nexus/
#
# # Load Balancing
# https://en.wikipedia.org/wiki/Load_balancing_(computing)
#
# # Scaling
#
# #### Intuitively Showing How To Scale A Web Application Using A Coffee Shop As An Example
# http://highscalability.com/blog/2014/3/17/intuitively-showing-how-to-scale-a-web-application-using-a-c.html
#
# #### DESIGNING A SCALABLE AND DISTRIBUTED APPLICATION
# https://ep2015.europython.eu/conference/talks/using-service-discovery-a-distributed-application
#
# Slides: https://docs.google.com/presentation/d/1bZ30UculKOM4IQ4ic5X2fLpz1Fe1QQPVqJLtshIO0pg/edit#slide=id.gb7f1517e4_0_4
#
# Source code: https://github.com/ultrabug/ep2015
#
# #### AWS July Webinar Series-Deploying and Scaling Web Application with AWS Elastic Beanstalk
# http://www.slideshare.net/AmazonWebServices/aws-july-webinar-seriesdeploying-and-scaling-web-application-with-aws-elastic-beanstalk
#
# #### Django Memcache
# https://devcenter.heroku.com/articles/django-memcache
#
# #### BUILDING SCALABLE WEB APPS Pycon 2011
# https://ep2013.europython.eu/conference/talks/building-scalable-web-apps
#
# https://ep2013.europython.eu/media/conference/slides/building-scalable-web-apps.pdf
#
# https://www.youtube.com/watch?v=cubJ4tYVrNc
#
# #### Building Scalable Web Sites - a good one
# http://www.cs.utah.edu/~grudy/Building%20Scalable%20Web%20Sites.pdf
#
# #### Building Scalable and Resilient Web Applications on Google Cloud Platform - a good one
# https://cloud.google.com/solutions/scalable-and-resilient-apps?hl=en
#
# #### Books
#  Building Scalable Web Sites: Building, scaling, and optimizing the
# next generation of web applications -- Cal Henderson
#
#  Scalable Internet Architectures -- Theo Schlossnagle
#
# #### Load Balancing
# http://tutorials.jenkov.com/software-architecture/load-balancing.html
#
# #### Introduction to Architecting Systems for Scale
# http://lethain.com/introduction-to-architecting-systems-for-scale/
#
# #### Web application performance and scalability - a good one
# http://www.webforefront.com/performance/index.html
#
# http://www.webforefront.com/performance/scaling101.html
