# %% [markdown]
# ### 337. House Robber III
# https://leetcode.com/problems/house-robber-iii/

# %%
from collections import deque

q = deque([])
q.append(0)
q.append('abc')
print len(q)
print q.popleft()
print q.popleft()
print 3%2
# Out:
# 2
# 0
# abc
# 1

# %%
#
# https://leetcode.com/problems/house-robber-iii/
#
# http://www.cs.berkeley.edu/~vazirani/s99cs170/notes/dynamic2.pdf
# http://stackoverflow.com/questions/10486089/finding-size-of-max-independent-set-in-binary-tree-why-faulty-solution-doesn

from collections import deque

# Definition for a binary tree node.
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None

class Solution(object):
    def _get_children(self,node):
        children = []
        if node.left:
            children.append(node.left)
        if node.right:
            children.append(node.right)
        return children
    
    def _mis(self,root,dict_mis):
        
        if root.left is None and root.right is None:
            if id(root) not in dict_mis:
                dict_mis[id(root)] = root.val
            return root.val
        
        without_root = 0
        with_root = root.val
        
        children = self._get_children(root)
        grand_children = []
        for n in children:
            grand_children.extend(self._get_children(n))
            
        for n in grand_children:
            if id(n) not in dict_mis:
                dict_mis[id(n)] = self._mis(n,dict_mis)
            with_root += dict_mis[id(n)]
            
        for n in children:
            if id(n) not in dict_mis:
                dict_mis[id(n)] = self._mis(n,dict_mis)
            without_root += dict_mis[id(n)]
            
        dict_mis[id(root)] = with_root if with_root >= without_root else without_root
        return dict_mis[id(root)]
    
    def rob(self, root):
        """
        :type root: TreeNode
        :rtype: int
        """
        if not root:
            return 0
        return self._mis(root, {})

                 
root = TreeNode(3)
root.left = TreeNode(2)
root.left.right = TreeNode(3)
root.right = TreeNode(3)
root.right.right = TreeNode(1)                 

print Solution().rob(root)

root = TreeNode(3)
root.left = TreeNode(4)
root.left.left = TreeNode(1)
root.left.right = TreeNode(3)
root.right = TreeNode(5)
root.right.right = TreeNode(1)  

print Solution().rob(root)

root = TreeNode(4)
root.left = TreeNode(1)
root.left.right = TreeNode(2)
root.left.right.right = TreeNode(3)

print Solution().rob(root)
# Out:
# 7
# 9
# 7

# %%
def solution ( true_root ):
    def get_children ( root_i ):
        return [ i for i in (2*root_i+1, 2*root_i+2) if i<len(true_root) ]
    def get_grandchildren ( root_i ):
        grand_children= []
        for i in get_children(root_i):
            grand_children.extend(get_children(i))
        return grand_children

    def find_max_independent ( root_i ):
        kids = get_children(root_i)
        grandkids = get_grandchildren(root_i)

        without_root = sum(map(find_max_independent, kids))
        with_root = sum(map(find_max_independent, grandkids))+ max(true_root[root_i],0)

        return max(with_root, without_root)

    return find_max_independent(0)

print solution([3,2,3,None,3,None,1])
print solution([4,1,None,None,2,None,None,None,None,None,3])
# Out:
# 7
# 7

# %% [markdown]
# ### 336. Palindrome Pairs
# https://leetcode.com/problems/palindrome-pairs/
#
# https://www.quora.com/Given-a-list-of-words-can-two-words-be-joined-together-to-form-a-palindrome

# %%
class Solution(object):
    def _is_palindrome(self,i,j):
        l1 = len(self.words[i])
        l2 = len(self.words[j])
        ij = True
        ji = True
        if l1 == l2:
            for k in range(l1):
                if self.words[i][k] != self.words[j][-k-1]:
                    ij = False
                    break
            for k in range(l1):
                if self.words[j][k] != self.words[i][-k-1]:
                    ji = False
                    break
        elif l1 < l2:
            for k in range(l1):
                if self.words[i][k] != self.words[j][-k-1]:
                    ij = False
                    break
            if ij:
                for k in range((l2-l1)/2):
                    if self.words[j][k] != self.words[j][-l1-k-1]:
                        ij = False
                        break
            for k in range(l1):
                if self.words[j][k] != self.words[i][-k-1]:
                    ji = False
                    break
            if ji:
                for k in range((l2-l1)/2):
                    if self.words[j][l1+k] != self.words[j][-k-1]:
                        ji = False
                        break
        else:
            for k in range(l2):
                if self.words[i][k] != self.words[j][-k-1]:
                    ij = False
                    break
            if ij:
                for k in range((l1-l2)/2):
                    if self.words[i][l2+k] != self.words[i][-k-1]:
                        ij = False
                        break
            for k in range(l2):
                if self.words[j][k] != self.words[i][-k-1]:
                    ji = False
                    break
            if ji:
                for k in range((l1-l2)/2):
                    if self.words[i][k] != self.words[i][-l2-k-1]:
                        ji = False
                        break
        if ij:
            self.result.append([i,j])
        if ji:
            self.result.append([j,i])
        
    def palindromePairs(self, words):
        """
        :type words: List[str]
        :rtype: List[List[int]]
        """
        self.words = words
        self.result = []
        for i in range(len(self.words)):
            for j in range(i+1,len(self.words)):
                self._is_palindrome(i,j)
        return self.result

words_01 = ["hfjdhccfbfhhhghde","jg","dhjdjida","f","dediagbhecegdghaaaid","icdabcebbhehhaahh","eibedacciaa","idfcdhgjgcjcgjig",
            "fhfidbggdghdibifeh","bageigab","eeahjicgdfgcbd","gfeg","g","hbjgiabh","cbhidai","bachcbdcjegcbdijgdfd",
            "icjccejafcaeci","cg","geddabbahgcghgihcica","bggadhcahhae","diejjefbjeb","eieahc","igdbccch","jfdhe",
            "j","hchdaggbjhiccgach","dhiad","ehjdjciehifgbg","hafggdfaeca","b","iddhacfijbiajffehi","icihfiea",
            "cjdechbidfhged","bbhdaecgabfega","bdifcbbhdaaabjj","dajfjhicfbddiciaeibi","hfgchhbhbhdhajhbi","gdifa",
            "bjdcefdjifjb","abeajjadjdfii","eeifadhabcfedbg","gaeadgicfg","hbjhcdaabaifahehfj","iiaebcihfjeaaiijc",
            "hhgidag","hecj","hcgibfbihgacicaj","aaabicdjb","jjjchiacjicfiegggc","bdaagfbeacjjh","eebgbajgie",
            "aaedcicjfbggdjefaaff","ggijjhecha","dcd","gceddjgjhfcfj","giefff","gibeceicg","edfdcbjgchicghcf",
            "djjcjdajjhijjjdhh","iggefcgbfg","jfhjjdcfbefiggcdgi","gadc","iebagfeejchcd","bhadjecgbfdfbabibadb",
            "fdeejfbhijdacfa","gigdedjjbdedgifgghj","ihhhhgib","bbeiiadjbgjfajdbijah","ac","jiacaaebejabfdf",
            "fcjiihhhbjbabbdg","fidgcgidaehbe","ahehh","ggigjddhajhdbafbahj","fhicijfejaabdejea","efjbgafebige",
            "dhdgfdcdfeifdjeebejd","dfjcjjidcghii","ddffjgeddg","egjheejjfjghgha","babgccegagcfidaaidd","jacdab",
            "gfdbb","fdhibbafeffgb","i","bfbbbhggcciie","aajdicfbgbife","deaeaafb","effajbch","ehiffebffadag",
            "beffdhdcbcfgfadfdb","cfbbaddi","gf","gcbecb","abhcbgigjei","efjcg","bdcjbbjfcfdceadjefg",
            "aaciaafbij","bhhbeaifdjfeaiijaec","jdhdbfhhgee","ehfidjgc","dfddbcabajcjbeefg","ghh","djifijij",
            "iaigcjcbdigchhghedg","ddcc","jejjahj","hjifjbaacceejjdihdah","adfbaefhga","cahdhbdagg",
            "adhifjhichjfiaaahb","fegebejefhieecjfa","jfgbhibhhfbjdjdgdg","fjdifb","igjieg","gcjddaebfefgdgddgii",
            "fecjdfbeea","cbja","hecaaejgaiac","cgfgh","cdahac","ge","iafadjffigibi","ggbefa","eeheghaffgbaehbid",
            "hedhbbebdefbj","ibgfbjdgdiedghighaic","igijagai","fdfehiiah","bicdehijdfjhfafe","ecgegfaecfcccbih",
            "fcdbfeejbgcfh","gidbejecbhdffafggedc","higafejifbcdhbd","bfa","ifffagi","gfhjhbadaebefbbccb",
            "edibbjccjhjedej","fcecacdaibidcdidiei","bbifdeaihihgciffdh","feibbeccaag","daij","dhea","ecgbdifaijaghih",
            "bbfaijcchahhjcbgg","cfehbghf","ccecheh","ijdeehbjfbgchjaf","dgeiahfjc","bbcfiegihi","afbaehbfjfihaibdfbc",
            "jjjhabiachcg","bfhfbaebhdccdgafb","bigfhggghi","cbfffieahcabjfejfbd","hcehicbjci","efbhiaah","jjddgj",
            "iejidbadjihgj","idd","jaie","bdfaiceedgcifbdad","diiciighejgba","hjchbcidchei","bgg","bgccegbbibjhigcjd",
            "ffbbbihbdhiefihc","ffiijahhihfjjeebchh","hchjcfegac","acjgc","ddijdhhcbaajjfa","hjfegegg","hebdjhffca",
            "gacbihhdibejihfeb","effihgid","eddhficecaicadgiadg","ccheaecb","dja","hhjfc","dagbgeea","gfifibejffh",
            "ecafchigbecdhbjbjga","ifgjjheegbfab","aegeabfgcbej","cg","gjcfb","c","jaacjhccaic","ajggcdieihgiieiccajc",
            "ig","ggcchafagiie","edffjb","ebchagi","g","ebjhfihhi","efdjhbjgbdb","gfgbjaifdfadfb","gdcfjaaeejjbfgagbef",
            "cjfgaehehbjc"]
s = Solution()
print s.palindromePairs(words_01)
print
print s.palindromePairs(words_02)
print
print s.palindromePairs(["bat", "tab", "cat"])
print
print s.palindromePairs(["abcd", "dcba", "lls", "s", "sssll"])
# Out:
# [[12, 1], [1, 24], [1, 170], [170, 1], [368, 1], [93, 3], [3, 232], [12, 17], [170, 12], [264, 12], [12, 304], [387, 12], [17, 108], [201, 17], [24, 170], [268, 24], [24, 274], [280, 24], [260, 29], [29, 267], [29, 280], [108, 68], [68, 126], [68, 315], [315, 68], [90, 84], [84, 200], [200, 84], [84, 224], [310, 84], [346, 84], [360, 90], [104, 251], [251, 104], [104, 267], [315, 108], [108, 345], [267, 126], [126, 315], [232, 168], [168, 268], [304, 168], [168, 310], [274, 188], [188, 280]]
#
# ...

# %%
print sorted(words_01)
# Out:
# ['a', 'aaabicdjb', 'aaabjehebgh', 'aabjhcidbfdehigfdij', 'aaedcicjfbggdjefaaff', 'aagfaj', 'aaidgiebhgaegagejc', 'aajdicfbgbife', 'ab', 'abeadgcgjhjbiahcjhij', 'abeajjadjdfii', 'abgeihfiihefdjjec', 'ac', 'acaiicgdeijajjbbjbih', 'aceaccbbgfecadihjee', 'acecjibeceec', 'adbfbbaag', 'addeci', 'addhbd', 'aeaghaiidde', 'aegababcgdecfjcgdghj', 'aehegcc', 'aeig', 'afdjiefjfcchcejhf', 'afgc', 'afiachijidbgb', 'afjcdbjgiedaahadada', 'agaij', 'agebeadadbacbhghf', 'agfgheea', 'agghc', 'aggih', 'agiafgdhgbciaahcc', 'ahagje', 'ahehh', 'ahffhgcagfjjib', 'ahfjcdibefdbgff', 'ahg', 'ahgfbeegjhighfdh', 'ahjeafafiadb', 'aibfjchihfca', 'aieabiafibidi', 'aieidehjjbcfhc', 'aiifigdbggef', 'ajggdbfa', 'ajigidibe', 'b', 'babgccegagcfidaaidd', 'bachcbdcjegcbdijgdfd', 'bagbejjdg', 'bageigab', 'bah', 'baiciahegiabj', 'baieeiabjigiedih', 'bbacha', 'bbccii', 'bbeiiadjbgjfajdbijah', 'bbhdaecgabfega', 'bcfbcbiafcjc', 'bcgfjigcbhehhdej', 'bdaagfbeacjjh', 'bdifcbbhdaaabjj', 'bdjddhcaieffega', 'beaegjeaibd', 'bebiaaab'
# ...

# %%
class TrieNode(object):
    def __init__(self):
        self.index = None
        self.is_palin = None
        self.children = {}
        
    def hasChild(self, cha):
        return cha in self.children
    
class Trie(object):
    def __init__(self):
        self.root = TrieNode()
        
    def find(self, key, inverse=False):
        if key is None:
            raise Exception('Invalid key.')
        key = key.strip()
        node = self.root
        if inverse:
            for i in range(len(key)):
                a = key[-i-1]
                if not node.hasChild(a):
                    return None
                node = node.children[a]
        else:
            for a in key:
                if not node.hasChild(a):
                    return None
                node = node.children[a]
        return dict(is_palin=node.is_palin, index=node.index)
    
    def insert(self, key, inx, isPalin=None, inverse=False):
        if key is None:
            raise Exception('Invalid key.')
        key = key.strip()
        node = self.root
        if inverse:
            for i in range(len(key)):
                a = key[-i-1]
                if not node.hasChild(a):
                    node.children[a] = TrieNode()
                node = node.children[a]
        else:
            for a in key:
                if not node.hasChild(a):
                    node.children[a] = TrieNode()
                node = node.children[a]
        if node.is_palin is None:
            node.is_palin = isPalin
        if node.index is not None:
            node.index.append(inx)
        else:
            node.index = [inx]
            
class Solution(object):
    def __init__(self):
        self.words = None
        self.directTrie = None
        self.inverseTrie = None
    def is_palindrome(self, word):
        if word is None:
            raise Exception('Invalid word.')
        for i in range(len(word)/2):
            if word[i] != word[-i-1]:
                return False
        return True
    def palindromePairs(self, words):
        """
        :type words: List[str]
        :rtype: List[List[int]]
        """
        self.words = words
        self.directTrie = Trie()
        self.reverseTrie = Trie()
        for i, word in enumerate(self.words):
            isPalin = self.is_palindrome(word)
            self.directTrie.insert(word, i, isPalin)
            self.inverseTrie.insert(word, i, isPalin, inverse=True)
