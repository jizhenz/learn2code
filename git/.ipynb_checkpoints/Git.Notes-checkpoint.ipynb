# %% [markdown]
# =================================================================================
# # Git Official Site:
# https://git-scm.com/
#
# =================================================================================
# # The book Pro GIT:
# https://git-scm.com/book/en/v2
#
# #### Git Commands
# https://git-scm.com/book/en/v2/Git-Commands-Setup-and-Config
#
# #### Git as a Client to Other Systems
#
# 4 systems covered in this book:
#
# SVN
#
# Hg
#
# Perforce
#
# TFS
#
# #### Migrate to Git
#
# 4 systems covered in this book:
#
# SVN
#
# Hg
#
# Perforce
#
# TFS
#
# And: A Custom Importer
#
# =================================================================================
# # Tutorials and Books
# https://git-scm.com/documentation/external-links
#
# # Reference Manual
# https://git-scm.com/docs
#
# # Cheat Sheet
# GitHub Git Cheat Sheet: https://training.github.com/kit/downloads/github-git-cheat-sheet.pdf
#
# Visual Git Cheat Sheet: http://justinhileman.info/article/git-pretty/git-pretty.png
#
# # Reset Demystified
#
# An excelent BLOG
#
# https://git-scm.com/blog
#
# =================================================================================
# # libgit2 - pure c cross platform implementation
# https://libgit2.github.com/
#
# 100% cross platform
#
# c89
#
# Zero dependencies
#
# Can be Embedded in your Applications
# https://git-scm.com/book/en/v2/Embedding-Git-in-your-Applications-Libgit2
#
# # pygit2 - Git Python Binding
# http://www.pygit2.org/
#
# =================================================================================
# # Git GUI Clients
# https://git-scm.com/downloads/guis
#
# =================================================================================
# # Git Source Code
# https://github.com/git/git
